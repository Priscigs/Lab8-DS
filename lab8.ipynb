# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
houses = pd.read_csv('houses_to_rent_v2.csv')

# %%
houses.head(3)
# Out:
#            city  area  rooms  bathroom  parking spaces floor animal  \
# 0     São Paulo    70      2         1               1     7  acept
# 1     São Paulo   320      4         4               0    20  acept
# 2  Porto Alegre    80      1         1               1     6  acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841

# %%
houses.tail(3)
# Out:
#                  city  area  rooms  bathroom  parking spaces floor     animal  \
# 10689  Rio de Janeiro    70      3         3               0     8  not acept
# 10690  Rio de Janeiro   120      2         2               2     8      acept
# 10691       São Paulo    80      2         1               0     -      acept
#
#            furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 10689      furnished       980              6000                332
# 10690      furnished      1585             12000                279
# 10691  not furnished         0              1400                165
#
#        fire insurance (R$)  total (R$)
# 10689                   78        7390
# 10690                  155       14020
# 10691                   22        1587

# %%
houses.describe()
# Out:
#                area         rooms      bathroom  parking spaces      hoa (R$)  \
# count  10692.000000  10692.000000  10692.000000    10692.000000  1.069200e+04
# mean     149.217920      2.506079      2.236813        1.609147  1.174022e+03
# std      537.016942      1.171266      1.407198        1.589521  1.559231e+04
# min       11.000000      1.000000      1.000000        0.000000  0.000000e+00
# 25%       56.000000      2.000000      1.000000        0.000000  1.700000e+02
# 50%       90.000000      2.000000      2.000000        1.000000  5.600000e+02
# 75%      182.000000      3.000000      3.000000        2.000000  1.237500e+03
# max    46335.000000     13.000000     10.000000       12.000000  1.117000e+06
#
#        rent amount (R$)  property tax (R$)  fire insurance (R$)    total (R$)
# count      10692.000000       10692.000000         10692.000000  1.069200e+04
# mean        3896.247194         366.704358            53.300879  5.490487e+03
# ...

# %%
sns.heatmap(houses.isnull(), yticklabels=False, cbar = False,cmap="Blues" )
# Out:
# <AxesSubplot:>

# %%
houses.isnull().sum()
# Out:
# city                   0
# area                   0
# rooms                  0
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %%
houses.hist(bins = 30, figsize = (12, 12), color = 'r')
# Out:
# array([[<AxesSubplot:title={'center':'area'}>,
#         <AxesSubplot:title={'center':'rooms'}>,
#         <AxesSubplot:title={'center':'bathroom'}>],
#        [<AxesSubplot:title={'center':'parking spaces'}>,
#         <AxesSubplot:title={'center':'hoa (R$)'}>,
#         <AxesSubplot:title={'center':'rent amount (R$)'}>],
#        [<AxesSubplot:title={'center':'property tax (R$)'}>,
#         <AxesSubplot:title={'center':'fire insurance (R$)'}>,
#         <AxesSubplot:title={'center':'total (R$)'}>]], dtype=object)

# %%
sns.pairplot(houses)

# %%
sns.heatmap(houses.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# !pip install -U pip
# !pip install -U setuptools wheel
# !pip install -U "mxnet<2.0.0"
# !pip install autogluon --no-cache-dir
# Out:
# ...
#    ---------------------------------------- 0.0/807.9 kB ? eta -:--:--
#    - -------------------------------------- 30.7/807.9 kB 1.3 MB/s eta 0:00:01
#    -- ------------------------------------ 61.4/807.9 kB 656.4 kB/s eta 0:00:02
#    ----- -------------------------------- 112.6/807.9 kB 819.2 kB/s eta 0:00:01
#    ----------- ---------------------------- 225.3/807.9 kB 1.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 225.3/807.9 kB 1.3 MB/s eta 0:00:01
#    ------------ --------------------------- 256.0/807.9 kB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 256.0/807.9 kB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 256.0/807.9 kB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 399.4/807.9 kB 1.0 MB/s eta 0:00:01
#    ------------------- -------------------- 399.4/807.9 kB 1.0 MB/s eta 0:00:01
#    ------------------- -------------------- 399.4/807.9 kB 1.0 MB/s eta 0:00:01
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_entreno, X_prueba = train_test_split(houses, test_size=0.2, random_state=0)

# %%
X_entreno
# Out:
#                 city  area  rooms  bathroom  parking spaces floor     animal  \
# 3083        Campinas    70      1         1               2     -      acept
# 508        São Paulo    40      1         1               1     9      acept
# 3079       São Paulo   113      3         4               3     5      acept
# 2036    Porto Alegre    40      2         1               1     3      acept
# 49          Campinas    48      1         1               1     2      acept
# ...              ...   ...    ...       ...             ...   ...        ...
# 9225  Rio de Janeiro    90      3         2               1     6      acept
# 4859       São Paulo   240      3         4               3     8      acept
# 3264  Rio de Janeiro   106      2         2               1     2      acept
# 9845       São Paulo   140      1         2               2     1  not acept
# 2732       São Paulo    67      2         1               0     3      acept
#
# ...

# %%
X_prueba
# Out:
#                  city  area  rooms  bathroom  parking spaces floor     animal  \
# 5474   Rio de Janeiro    95      3         2               1     6      acept
# 1167        São Paulo   100      3         2               2    10  not acept
# 3156        São Paulo   130      2         1               1     -      acept
# 124         São Paulo    94      3         3               2     3      acept
# 1158         Campinas   111      3         3               3     6  not acept
# ...               ...   ...    ...       ...             ...   ...        ...
# 5378         Campinas   130      3         2               6     -      acept
# 8636        São Paulo   134      3         3               2    18      acept
# 10185       São Paulo    36      1         1               1    11  not acept
# 8348        São Paulo    73      2         2               1    13      acept
# 2357        São Paulo    60      2         2               1     8      acept
#
# ...

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
predictor = TabularPredictor(label='total (R$)',
                             problem_type = 'regression', 
                             eval_metric = 'rmse').fit(train_data = X_entreno,
                                                         time_limit=300,
                                                         presets='best_quality'
                                                         )
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20231027_092931\"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 300s
# AutoGluon will save models to "AutogluonModels\ag-20231027_092931\"
# AutoGluon Version:  0.8.2
# Python Version:     3.10.0
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# Disk Space Avail:   536.73 GB / 998.95 GB (53.7%)
# Train Data Rows:    8553
# Train Data Columns: 12
# Label Column: total (R$)
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5353.77 MB
# 	Train Data (Original)  Memory Usage: 2.92 MB (0.1% of available memory)
# ...
